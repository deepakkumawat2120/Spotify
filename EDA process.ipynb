# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\hp\AppData\Local\Programs\Python\Python39\BillBoard\billboard.csv")

# %%
#1 UNDERSTANDING THE DATA

# %%
data.head()
# Out:
#   ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')  \
# 0  ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 1  ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 2  ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 3          ('In My Feelings', 'Drake', '2018-09-22')
# 4          ('In My Feelings', 'Drake', '2018-09-15')
#
#         ('Lucid Dreams', 'Juice WRLD', '2018-10-20')  \
# 0  ('Mona Lisa', 'Lil Wayne Featuring Kendrick La...
# 1       ('Lucid Dreams', 'Juice WRLD', '2018-10-06')
# 2          ('In My Feelings', 'Drake', '2018-09-29')
# 3  ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 4  ('Girls Like You', 'Maroon 5 Featuring Cardi B...
#
#          ('Better Now', 'Post Malone', '2018-10-20')  \
# 0       ('Lucid Dreams', 'Juice WRLD', '2018-10-13')
# 1        ('Better Now', 'Post Malone', '2018-10-06')
# 2               ('Killshot', 'Eminem', '2018-09-29')
# 3  ('I Like It', 'Cardi B, Bad Bunny & J Balvin',...
# ...

# %%
data.tail()
# Out:
#      ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')  \
# 1498  ('How Am I Supposed To Live Without You', 'Mic...
# 1499  ('How Am I Supposed To Live Without You', 'Mic...
# 1500  ('How Am I Supposed To Live Without You', 'Mic...
# 1501  ('Another Day In Paradise', 'Phil Collins', '1...
# 1502  ('Another Day In Paradise', 'Phil Collins', '1...
#
#            ('Lucid Dreams', 'Juice WRLD', '2018-10-20')  \
# 1498  ('Opposites Attract', 'Paula Abdul (Duet With ...
# 1499  ('Pump Up The Jam', 'Technotronic Featuring Fe...
# 1500  ('Pump Up The Jam', 'Technotronic Featuring Fe...
# 1501   ('Rhythm Nation', 'Janet Jackson', '1990-01-13')
# 1502   ('Rhythm Nation', 'Janet Jackson', '1990-01-06')
#
#             ('Better Now', 'Post Malone', '2018-10-20')  \
# 1498    ('Downtown Train', 'Rod Stewart', '1990-02-03')
# 1499    ('Downtown Train', 'Rod Stewart', '1990-01-27')
# 1500  ('Another Day In Paradise', 'Phil Collins', '1...
# ...

# %%
data.describe()
# Out:
#        ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')  \
# count                                                1503
# unique                                               1503
# top     ("She Ain't Worth It", 'Glenn Medeiros Featuri...
# freq                                                    1
#
#        ('Lucid Dreams', 'Juice WRLD', '2018-10-20')  \
# count                                          1503
# unique                                         1503
# top            ('Joyride', 'Roxette', '1991-04-27')
# freq                                              1
#
#               ('Better Now', 'Post Malone', '2018-10-20')  \
# count                                                1503
# unique                                               1503
# top     ('Nuthin\' But A "G" Thang', 'Dr. Dre', '1993-...
# freq                                                    1
#
#        ('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')  \
# ...

# %%
data.shape
# Out:
# (1503, 100)

# %%
data.columns
# Out:
# Index(['('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')',
#        '('Lucid Dreams', 'Juice WRLD', '2018-10-20')',
#        '('Better Now', 'Post Malone', '2018-10-20')',
#        '('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')',
#        '('Shallow', 'Lady Gaga & Bradley Cooper', '2018-10-20')',
#        '('Sicko Mode', 'Travis Scott', '2018-10-20')',
#        '('Youngblood', '5 Seconds Of Summer', '2018-10-20')',
#        '('Happier', 'Marshmello & Bastille', '2018-10-20')',
#        '('I Like It', 'Cardi B, Bad Bunny & J Balvin', '2018-10-20')',
#        '('FEFE', '6ix9ine Featuring Nicki Minaj & Murda Beatz', '2018-10-20')',
#        '('In My Feelings', 'Drake', '2018-10-20')',
#        '('Love Lies', 'Khalid & Normani', '2018-10-20')',
#        '('Natural', 'Imagine Dragons', '2018-10-20')',
#        '('Taste', 'Tyga Featuring Offset', '2018-10-20')',
#        '('Never Recover', 'Lil Baby & Gunna Featuring Drake', '2018-10-20')',
# ...

# %%
data.nunique()
# Out:
# ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')    1503
# ('Lucid Dreams', 'Juice WRLD', '2018-10-20')                      1503
# ('Better Now', 'Post Malone', '2018-10-20')                       1503
# ('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')               1503
# ('Shallow', 'Lady Gaga & Bradley Cooper', '2018-10-20')           1503
#                                                                   ...
# ('Drunk Girl', 'Chris Janson', '2018-10-20')                      1503
# ('Deep End', 'Lil Baby', '2018-10-20')                            1503
# ('I Am', 'Lil Baby & Gunna', '2018-10-20')                        1503
# ('Sunrise, Sunburn, Sunset', 'Luke Bryan', '2018-10-20')          1503
# ('Noticed', 'Lil Mosey', '2018-10-20')                            1503
# Length: 100, dtype: int64

# %%
data["('Better Now', 'Post Malone', '2018-10-20')"].unique()
# Out:
# array(["('Lucid Dreams', 'Juice WRLD', '2018-10-13')",
#        "('Better Now', 'Post Malone', '2018-10-06')",
#        "('Killshot', 'Eminem', '2018-09-29')", ...,
#        "('Another Day In Paradise', 'Phil Collins', '1990-01-20')",
#        "('Pump Up The Jam', 'Technotronic Featuring Felly', '1990-01-13')",
#        '("Don\'t Know Much", \'Linda Ronstadt (Featuring Aaron Neville)\', \'1990-01-06\')'],
#       dtype=object)

# %%
data["('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')"].unique()
# Out:
# array(["('Better Now', 'Post Malone', '2018-10-13')",
#        "('In My Feelings', 'Drake', '2018-10-06')",
#        "('Lucid Dreams', 'Juice WRLD', '2018-09-29')", ...,
#        "('Everything', 'Jody Watley', '1990-01-20')",
#        "('How Am I Supposed To Live Without You', 'Michael Bolton', '1990-01-13')",
#        "('Pump Up The Jam', 'Technotronic Featuring Felly', '1990-01-06')"],
#       dtype=object)

# %%
#CLEANING THE DATA

# %%
data.isnull().sum()
# Out:
# ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')    0
# ('Lucid Dreams', 'Juice WRLD', '2018-10-20')                      0
# ('Better Now', 'Post Malone', '2018-10-20')                       0
# ('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')               0
# ('Shallow', 'Lady Gaga & Bradley Cooper', '2018-10-20')           0
#                                                                  ..
# ('Drunk Girl', 'Chris Janson', '2018-10-20')                      0
# ('Deep End', 'Lil Baby', '2018-10-20')                            0
# ('I Am', 'Lil Baby & Gunna', '2018-10-20')                        0
# ('Sunrise, Sunburn, Sunset', 'Luke Bryan', '2018-10-20')          0
# ('Noticed', 'Lil Mosey', '2018-10-20')                            0
# Length: 100, dtype: int64

# %%
df1= data.dropna(axis=1)
print(df1)
# Out:
#      ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')  \
# 0     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 1     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 2     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 3             ('In My Feelings', 'Drake', '2018-09-22')
# 4             ('In My Feelings', 'Drake', '2018-09-15')
# ...                                                 ...
# 1498  ('How Am I Supposed To Live Without You', 'Mic...
# 1499  ('How Am I Supposed To Live Without You', 'Mic...
# 1500  ('How Am I Supposed To Live Without You', 'Mic...
# 1501  ('Another Day In Paradise', 'Phil Collins', '1...
# 1502  ('Another Day In Paradise', 'Phil Collins', '1...
#
#            ('Lucid Dreams', 'Juice WRLD', '2018-10-20')  \
# 0     ('Mona Lisa', 'Lil Wayne Featuring Kendrick La...
# 1          ('Lucid Dreams', 'Juice WRLD', '2018-10-06')
# 2             ('In My Feelings', 'Drake', '2018-09-29')
# ...

# %%
df2 = data.dropna()
print(df2)
# Out:
#      ('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')  \
# 0     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 1     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 2     ('Girls Like You', 'Maroon 5 Featuring Cardi B...
# 3             ('In My Feelings', 'Drake', '2018-09-22')
# 4             ('In My Feelings', 'Drake', '2018-09-15')
# ...                                                 ...
# 1498  ('How Am I Supposed To Live Without You', 'Mic...
# 1499  ('How Am I Supposed To Live Without You', 'Mic...
# 1500  ('How Am I Supposed To Live Without You', 'Mic...
# 1501  ('Another Day In Paradise', 'Phil Collins', '1...
# 1502  ('Another Day In Paradise', 'Phil Collins', '1...
#
#            ('Lucid Dreams', 'Juice WRLD', '2018-10-20')  \
# 0     ('Mona Lisa', 'Lil Wayne Featuring Kendrick La...
# 1          ('Lucid Dreams', 'Juice WRLD', '2018-10-06')
# 2             ('In My Feelings', 'Drake', '2018-09-29')
# ...

# %%
Song = data.drop(["('Girls Like You', 'Maroon 5 Featuring Cardi B', '2018-10-20')","('Lucid Dreams', 'Juice WRLD', '2018-10-20')"], axis = 1)

# %%
Song.head()
# Out:
#          ('Better Now', 'Post Malone', '2018-10-20')  \
# 0       ('Lucid Dreams', 'Juice WRLD', '2018-10-13')
# 1        ('Better Now', 'Post Malone', '2018-10-06')
# 2               ('Killshot', 'Eminem', '2018-09-29')
# 3  ('I Like It', 'Cardi B, Bad Bunny & J Balvin',...
# 4  ('I Like It', 'Cardi B, Bad Bunny & J Balvin',...
#
#   ('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20')  \
# 0        ('Better Now', 'Post Malone', '2018-10-13')
# 1          ('In My Feelings', 'Drake', '2018-10-06')
# 2       ('Lucid Dreams', 'Juice WRLD', '2018-09-29')
# 3        ('Better Now', 'Post Malone', '2018-09-22')
# 4  ('FEFE', '6ix9ine Featuring Nicki Minaj & Murd...
#
#   ('Shallow', 'Lady Gaga & Bradley Cooper', '2018-10-20')  \
# 0  ("Don't Cry", 'Lil Wayne Featuring XXXTENTACIO...
# 1               ('Killshot', 'Eminem', '2018-10-06')
# 2        ('Better Now', 'Post Malone', '2018-09-29')
# 3       ('Lucid Dreams', 'Juice WRLD', '2018-09-22')
# ...

# %%
#RELATIOSHIP ANALYSIS

# %%
corelation = Song.corr()

# %%
sns.heatmap(corelation,  annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x=('Better Now', 'Post Malone', '2018-10-20'), y=('Drip Too Hard', 'Lil Baby & Gunna', '2018-10-20'), hue=('Shallow', 'Lady Gaga & Bradley Cooper', '2018-10-20'))

# %%
sns.distplot(Song["('Better Now', 'Post Malone', '2018-10-20')"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-af143396afad> in <module>
# ----> 1 sns.distplot(Song["('Better Now', 'Post Malone', '2018-10-20')"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2572
#    2573     # Make a a 1-d float array
# -> 2574     a = np.asarray(a, float)
#    2575     if a.ndim > 1:
#    2576         a = a.squeeze()
#
# ...
